# %%
# !python saturday.py
# Out:
# 2025-05-17 15:55:23,834 - INFO - Using device: cuda
# 2025-05-17 15:55:23,834 - INFO - --- Initializing Datasets and Performing Subject-Aware Splits ---
# 2025-05-17 15:55:23,894 - INFO - Total valid files found: 352
# 2025-05-17 15:55:23,895 - ERROR - GroupShuffleSplit failed: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all(). This can happen with small datasets/groups or if a split results in zero samples. Consider reviewing data or split proportions.
# 2025-05-17 15:55:23,895 - INFO - Attempting fallback to original stratified split (not group-aware). THIS MAY INTRODUCE LEAKAGE if subjects have multiple files.
# 2025-05-17 15:55:23,896 - INFO - Fallback to original stratified split successful (BUT NOT GROUP-AWARE).
# 2025-05-17 15:55:23,896 - INFO - Creating dataset (fit_scalers=True) with 224 files planned...
# 2025-05-17 15:55:24,032 - INFO - Actual dataset size after loading: 224
# ...
