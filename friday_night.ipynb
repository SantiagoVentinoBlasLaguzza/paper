# %%
# !python friday_night.py
# Out:
# 2025-05-17 01:41:42,482 - INFO - Using device: cuda
# 2025-05-17 01:41:42,483 - INFO - --- Initializing Datasets ---
# 2025-05-17 01:41:42,549 - INFO - Successfully performed stratified splits.
# 2025-05-17 01:41:42,550 - INFO - Creating dataset (fit_scalers=True) with 224 files...
# 2025-05-17 01:41:42,674 - INFO - Creating dataset (fit_scalers=False) with 57 files...
# 2025-05-17 01:41:42,691 - INFO - Creating dataset (fit_scalers=False) with 71 files...
# 2025-05-17 01:41:42,714 - INFO - CVAE Train set: 224, CVAE Validation set: 57, Final Test set: 71
# 2025-05-17 01:41:43,380 - INFO -
# --- Training CVAE with ResNet Encoder (on AD, CN, Other) ---
# 2025-05-17 01:41:44,190 - INFO - CVAE Epoch 1/400: Beta_KL: 0.0502 Capacity_C: 0.31 LR: 1.0e-04
#   Train Loss: 5344.1247 (Recon: 5343.9361, KL: 4.0689)
#   Val Loss  : 3382.8850 (Recon: 3382.8818, KL: 0.3770)
# 2025-05-17 01:41:44,190 - INFO - Validation loss decreased (inf --> 3382.885010). Saving model ...
# ...
