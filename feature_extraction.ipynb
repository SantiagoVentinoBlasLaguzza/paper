# %%
# !python feature_extraction.py --subject_list_csv DataBaseSubjects.csv --roi_signals_dir ROISignals/ --output_dir matrix/ --tr 3.0
# Out:
# INFO: --data_is_pre_detrended. Internal detrend skipped (ignoring --detrend_poly_order=1).
# 2025-05-16 13:04:54,311 INFO [MainProcess]: Pipeline v10.1 (Adapted for 116 ROIs and variable timepoints)...
# ...
