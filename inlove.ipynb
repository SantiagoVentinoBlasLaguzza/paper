# %%
# !python friday_inlove.py
# Out:
# 2025-05-17 12:16:35,089 - INFO - Using device: cuda
# 2025-05-17 12:16:35,089 - INFO - --- Initializing Datasets ---
# 2025-05-17 12:16:35,154 - INFO - Successfully performed stratified splits.
# 2025-05-17 12:16:35,154 - INFO - Creating dataset (fit_scalers=True) with 224 files...
# 2025-05-17 12:16:35,283 - INFO - Creating dataset (fit_scalers=False) with 57 files...
# 2025-05-17 12:16:35,303 - INFO - Creating dataset (fit_scalers=False) with 71 files...
# 2025-05-17 12:16:35,325 - INFO - CVAE Train set: 224, CVAE Validation set: 57, Final Test set: 71
# 2025-05-17 12:16:36,054 - INFO -
# --- Training CVAE with ResNet Encoder (on AD, CN, Other) ---
# 2025-05-17 12:16:37,078 - INFO - CVAE Epoch 1/400: Beta_KL: 0.0502 Capacity_C: 0.31 LR: 1.0e-04
#   Train Loss: 5209.1657 (Recon: 5208.7861, KL: 7.8729)
#   Val Loss  : 5207.7451 (Recon: 5207.3655, KL: 7.8712)
# 2025-05-17 12:16:37,078 - INFO - Validation loss decreased (inf --> 5207.745117). Saving model ...
# ...
